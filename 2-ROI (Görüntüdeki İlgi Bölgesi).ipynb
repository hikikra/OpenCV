# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('avengers.jpg')

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
print(img.shape[:2])
# Out:
# (273, 184)

# %%
roi = img[10:80, 55:110]

# %%
plt.imshow(roi)

# %%
plt.imshow(roi)
plt.xticks([]), plt.yticks([])
plt.show()
