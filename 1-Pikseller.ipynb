# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('avengers.jpg')

# %%
plt.imshow(img)

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #BGR-dan RGB-ye dönüş

# %%
plt.imshow(img2)

# %%
img3 = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(img3)

# %%
img4 = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)

# %%
plt.imshow(img4)

# %%
img5 = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

# %%
plt.imshow(img5)

# %%
img6 = cv2.cvtColor(img, cv2.COLOR_BGR2XYZ)

# %%
plt.imshow(img6)

# %%
img2.shape
# Out:
# (273, 184, 3)

# %%
renk = img2[10,160]
print(renk)
# Out:
# [ 0  2 12]

# %%
kirmizi = img2[25,120,0] # 0 kırmızıyı temsil eder
print('kirmizi :',kirmizi)

yesil = img2[25,120,1] # 1 yeşili temsil eder
print('yesil :',yesil)

mavi = img2[25,120,2] # 2 maviyi temsil eder
print('mavi :',mavi)
# Out:
# kirmizi : 26
# yesil : 18
# mavi : 117
